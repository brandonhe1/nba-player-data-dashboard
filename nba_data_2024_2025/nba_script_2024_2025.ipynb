# %%
from nba_api.stats.static import teams
from nba_api.stats.endpoints import commonteamroster, playercareerstats, shotchartdetail
import pandas as pd
import requests
import time

# %%
nba_teams = teams.get_teams()

# %%
def fetch_roster_with_retry(team_id, max_attempts=3):
    for attempt in range(1, max_attempts+1):
        try:
            roster = commonteamroster.CommonTeamRoster(team_id=team_id, season='2024-25')
            roster_df = roster.get_data_frames()[0]
            print(f"  ✅ Got roster for team {team_id} (Attempt {attempt})")
            return roster_df
        except Exception as e:
            print(f"  ⚠️ Attempt {attempt} failed for roster {team_id}: {e}")
            time.sleep(2)
    print(f"  ❌ Failed to get roster for team {team_id} after {max_attempts} attempts.")
    return None


def fetch_player_shotchart(player_id, team_id, player_name, team_name, season='2024-25', season_type='Regular Season', max_attempts=5):
    """
    Fetches shot chart data with retries and session resets.
    Returns a DataFrame or None if all attempts fail.
    """
    for attempt in range(1, max_attempts + 1):
        try:
            session = requests.Session()
            session.headers.update({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'})
            shots = shotchartdetail.ShotChartDetail(
                team_id=team_id,
                player_id=player_id,
                season_nullable=season,
                season_type_all_star=season_type,
                timeout=60,
                session=session
            )
            shots_df = shots.get_data_frames()[0]
            shots_df['PLAYER_ID'] = player_id
            shots_df['PLAYER_NAME'] = player_name
            shots_df['TEAM_NAME'] = team_name
            print(f"  ✅ Got {len(shots_df)} shots for {player_name} (Attempt {attempt})")
            return shots_df
        except Exception as e:
            print(f"  ⚠️ Attempt {attempt} failed for {player_name}: {e}")
            time.sleep(5)
    print(f"  ❌ Failed to get shots for {player_name} after {max_attempts} attempts.")
    return None

# %%
# Fetch data for each player on every team

all_players_data = []
all_shots_data = []

for team in nba_teams:
    team_id = team['id']
    team_name = team['full_name']
    print(f"\nFetching roster for {team_name}...")

    roster_df = fetch_roster_with_retry(team_id)
    if roster_df is None:
        continue

    for _, player in roster_df.iterrows():
        player_id = player['PLAYER_ID']
        player_name = player['PLAYER']
        position = player['POSITION']
        height = player['HEIGHT']
        weight = player['WEIGHT']

        # Player stats
        try:
            career = playercareerstats.PlayerCareerStats(player_id=player_id)
            stats_df = career.get_data_frames()[0]
            season_stats = stats_df[stats_df['SEASON_ID'] == '2024-25']
            if not season_stats.empty:
                stats = season_stats.iloc[0]
                ppg = stats['PTS'] / stats['GP'] if stats['GP'] > 0 else 0
                rpg = stats['REB'] / stats['GP'] if stats['GP'] > 0 else 0
                apg = stats['AST'] / stats['GP'] if stats['GP'] > 0 else 0
                spg = stats['STL'] / stats['GP'] if stats['GP'] > 0 else 0
                bpg = stats['BLK'] / stats['GP'] if stats['GP'] > 0 else 0
            else:
                ppg = rpg = apg = spg = bpg = 0
        except:
            ppg = rpg = apg = spg = bpg = 0

        headshot_url = f"https://cdn.nba.com/headshots/nba/latest/1040x760/{player_id}.png"

        all_players_data.append({
            'Player': player_name,
            'Team': team_name,
            'Position': position,
            'Height': height,
            'Weight': weight,
            'PPG': round(ppg, 1),
            'RPG': round(rpg, 1),
            'APG': round(apg, 1),
            'SPG': round(spg, 1),
            'BPG': round(bpg, 1),
            'Headshot_URL': headshot_url
        })

        # Shot chart fetching remains the same
        try:
            shots = shotchartdetail.ShotChartDetail(
                team_id=team_id,
                player_id=player_id,
                season_nullable='2024-25',
                season_type_all_star='Regular Season'
            )
            shots_df = shots.get_data_frames()[0]
            shots_df['PLAYER_ID'] = player_id
            shots_df['PLAYER_NAME'] = player_name
            shots_df['TEAM_NAME'] = team_name
            all_shots_data.append(shots_df)
        except Exception as e:
            print(f"  ⚠️ Could not get shots for {player_name}: {e}")

        time.sleep(0.6)  # short delay between players

    # Partial save after each team
    pd.DataFrame(all_players_data).to_csv("nba_player_cards_2024_25.csv", index=False)
    if all_shots_data:
        pd.concat(all_shots_data, ignore_index=True).to_csv("nba_shotchart_data_2024_25.csv", index=False)

    time.sleep(2)  # delay before fetching next team

print("✅ Finished fetching all player stats and shot charts!")
# Out:
# Fetching roster for Atlanta Hawks...
#   ✅ Got roster for team 1610612737 (Attempt 1)
#
# Fetching roster for Boston Celtics...
#   ✅ Got roster for team 1610612738 (Attempt 1)
#
# Fetching roster for Cleveland Cavaliers...
#   ✅ Got roster for team 1610612739 (Attempt 1)
#
# Fetching roster for New Orleans Pelicans...
#   ✅ Got roster for team 1610612740 (Attempt 1)
#
# Fetching roster for Chicago Bulls...
#   ✅ Got roster for team 1610612741 (Attempt 1)
#
# Fetching roster for Dallas Mavericks...
#   ✅ Got roster for team 1610612742 (Attempt 1)
#
# Fetching roster for Denver Nuggets...
#   ✅ Got roster for team 1610612743 (Attempt 1)
#
# Fetching roster for Golden State Warriors...
#   ✅ Got roster for team 1610612744 (Attempt 1)
#
# Fetching roster for Houston Rockets...
#   ✅ Got roster for team 1610612745 (Attempt 1)
#
# Fetching roster for Los Angeles Clippers...
#   ✅ Got roster for team 1610612746 (Attempt 1)
#
# Fetching roster for Los Angeles Lakers...
#   ✅ Got roster for team 1610612747 (Attempt 1)
#
# Fetching roster for Miami Heat...
#   ✅ Got roster for team 1610612748 (Attempt 1)
#
# Fetching roster for Milwaukee Bucks...
#   ✅ Got roster for team 1610612749 (Attempt 1)
#
# Fetching roster for Minnesota Timberwolves...
#   ✅ Got roster for team 1610612750 (Attempt 1)
#
# Fetching roster for Brooklyn Nets...
#   ✅ Got roster for team 1610612751 (Attempt 1)
#
# Fetching roster for New York Knicks...
#   ✅ Got roster for team 1610612752 (Attempt 1)
#
# Fetching roster for Orlando Magic...
#   ✅ Got roster for team 1610612753 (Attempt 1)
#   ⚠️ Could not get shots for Trevelin Queen: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Could not get shots for Jett Howard: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Could not get shots for Gary Harris: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Could not get shots for Moritz Wagner: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Could not get shots for Franz Wagner: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Could not get shots for Tristan da Silva: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Could not get shots for Wendell Carter Jr.: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Could not get shots for Goga Bitadze: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Could not get shots for Ethan Thompson: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#
# Fetching roster for Indiana Pacers...
#   ⚠️ Attempt 1 failed for roster 1610612754: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 2 failed for roster 1610612754: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 3 failed for roster 1610612754: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ❌ Failed to get roster for team 1610612754 after 3 attempts.
#
# Fetching roster for Philadelphia 76ers...
#   ⚠️ Attempt 1 failed for roster 1610612755: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Attempt 2 failed for roster 1610612755: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 3 failed for roster 1610612755: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ❌ Failed to get roster for team 1610612755 after 3 attempts.
#
# Fetching roster for Phoenix Suns...
#   ⚠️ Attempt 1 failed for roster 1610612756: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 2 failed for roster 1610612756: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 3 failed for roster 1610612756: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ❌ Failed to get roster for team 1610612756 after 3 attempts.
#
# Fetching roster for Portland Trail Blazers...
#   ⚠️ Attempt 1 failed for roster 1610612757: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 2 failed for roster 1610612757: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 3 failed for roster 1610612757: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ❌ Failed to get roster for team 1610612757 after 3 attempts.
#
# Fetching roster for Sacramento Kings...
#   ⚠️ Attempt 1 failed for roster 1610612758: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Attempt 2 failed for roster 1610612758: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 3 failed for roster 1610612758: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ❌ Failed to get roster for team 1610612758 after 3 attempts.
#
# Fetching roster for San Antonio Spurs...
#   ⚠️ Attempt 1 failed for roster 1610612759: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Attempt 2 failed for roster 1610612759: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 3 failed for roster 1610612759: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ❌ Failed to get roster for team 1610612759 after 3 attempts.
#
# Fetching roster for Oklahoma City Thunder...
#   ⚠️ Attempt 1 failed for roster 1610612760: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 2 failed for roster 1610612760: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 3 failed for roster 1610612760: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ❌ Failed to get roster for team 1610612760 after 3 attempts.
#
# Fetching roster for Toronto Raptors...
#   ⚠️ Attempt 1 failed for roster 1610612761: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 2 failed for roster 1610612761: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 3 failed for roster 1610612761: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ❌ Failed to get roster for team 1610612761 after 3 attempts.
#
# Fetching roster for Utah Jazz...
#   ⚠️ Attempt 1 failed for roster 1610612762: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 2 failed for roster 1610612762: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 3 failed for roster 1610612762: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ❌ Failed to get roster for team 1610612762 after 3 attempts.
#
# Fetching roster for Memphis Grizzlies...
#   ⚠️ Attempt 1 failed for roster 1610612763: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 2 failed for roster 1610612763: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Attempt 3 failed for roster 1610612763: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ❌ Failed to get roster for team 1610612763 after 3 attempts.
#
# Fetching roster for Washington Wizards...
#   ⚠️ Attempt 1 failed for roster 1610612764: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 2 failed for roster 1610612764: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 3 failed for roster 1610612764: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ❌ Failed to get roster for team 1610612764 after 3 attempts.
#
# Fetching roster for Detroit Pistons...
#   ⚠️ Attempt 1 failed for roster 1610612765: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 2 failed for roster 1610612765: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 3 failed for roster 1610612765: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ❌ Failed to get roster for team 1610612765 after 3 attempts.
#
# Fetching roster for Charlotte Hornets...
#   ⚠️ Attempt 1 failed for roster 1610612766: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ⚠️ Attempt 2 failed for roster 1610612766: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ⚠️ Attempt 3 failed for roster 1610612766: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#   ❌ Failed to get roster for team 1610612766 after 3 attempts.
# ✅ Finished fetching all player stats and shot charts!

# %% [markdown]
# Due to nba_api rate limits, the script timeouts at Trevelin Queen (Orlando Magic). This second part of the notebook is to finish obtaining the data for the rest of the players.

# %%
players_path = "nba_player_cards_2024_25.csv"
shots_path = "nba_shotchart_data_2024_25.csv"

try:
    existing_players = pd.read_csv(players_path)
    processed_players = set(existing_players['Player'])
    print(f"✅ Loaded {len(existing_players)} players already processed.")
except FileNotFoundError:
    existing_players = pd.DataFrame()
    processed_players = set()
    print("ℹ️ No existing player data found — starting fresh.")

try:
    existing_shots = pd.read_csv(shots_path)
except FileNotFoundError:
    existing_shots = pd.DataFrame()
# Out:
# ✅ Loaded 301 players already processed.

# %%
def fetch_with_retry(fetch_fn, max_attempts=3, delay=5):
    for attempt in range(1, max_attempts + 1):
        try:
            return fetch_fn()
        except Exception as e:
            print(f"  ⚠️ Attempt {attempt} failed: {e}")
            if attempt < max_attempts:
                time.sleep(delay)
            else:
                print("  ❌ Giving up after 3 attempts.")
                return None

# --- Get Roster with Retry ---
def fetch_roster_with_retry(team_id):
    return fetch_with_retry(lambda: commonteamroster.CommonTeamRoster(team_id=team_id, season='2024-25').get_data_frames()[0])

# --- Main Loop ---
for team in nba_teams:
    team_id = team['id']
    team_name = team['full_name']
    print(f"\nFetching roster for {team_name}...")

    roster_df = fetch_roster_with_retry(team_id)
    if roster_df is None:
        continue

    new_players = []
    new_shots = []

    for _, player in roster_df.iterrows():
        player_id = player['PLAYER_ID']
        player_name = player['PLAYER']

        # Skip if already processed
        if player_name in processed_players:
            print(f"⏭️ Skipping {player_name} (already saved)")
            continue

        position = player['POSITION']
        height = player['HEIGHT']
        weight = player['WEIGHT']

        # --- Player Stats ---
        try:
            career = fetch_with_retry(lambda: playercareerstats.PlayerCareerStats(player_id=player_id))
            if career is not None:
                stats_df = career.get_data_frames()[0]
                season_stats = stats_df[stats_df['SEASON_ID'] == '2024-25']
                if not season_stats.empty:
                    stats = season_stats.iloc[0]
                    gp = stats['GP'] if stats['GP'] > 0 else 1
                    ppg = stats['PTS'] / gp
                    rpg = stats['REB'] / gp
                    apg = stats['AST'] / gp
                    spg = stats['STL'] / gp
                    bpg = stats['BLK'] / gp
                else:
                    ppg = rpg = apg = spg = bpg = 0
            else:
                ppg = rpg = apg = spg = bpg = 0
        except Exception as e:
            print(f"  ⚠️ Could not get stats for {player_name}: {e}")
            ppg = rpg = apg = spg = bpg = 0

        headshot_url = f"https://cdn.nba.com/headshots/nba/latest/1040x760/{player_id}.png"

        new_players.append({
            'Player': player_name,
            'Team': team_name,
            'Position': position,
            'Height': height,
            'Weight': weight,
            'PPG': round(ppg, 1),
            'RPG': round(rpg, 1),
            'APG': round(apg, 1),
            'SPG': round(spg, 1),
            'BPG': round(bpg, 1),
            'Headshot_URL': headshot_url
        })

        # --- Shot Chart ---
        try:
            shots = fetch_with_retry(lambda: shotchartdetail.ShotChartDetail(
                team_id=team_id,
                player_id=player_id,
                season_nullable='2024-25',
                season_type_all_star='Regular Season'
            ))
            if shots is not None:
                shots_df = shots.get_data_frames()[0]
                shots_df['PLAYER_ID'] = player_id
                shots_df['PLAYER_NAME'] = player_name
                shots_df['TEAM_NAME'] = team_name
                new_shots.append(shots_df)
                print(f"  ✅ Got {len(shots_df)} shots for {player_name}")
            else:
                print(f"  ⚠️ No shots for {player_name}")
        except Exception as e:
            print(f"  ⚠️ Could not get shots for {player_name}: {e}")

        # short delay between players
        time.sleep(0.7)

    # --- Append and Save ---
    if new_players:
        new_players_df = pd.DataFrame(new_players)
        combined_players = pd.concat([existing_players, new_players_df], ignore_index=True)
        combined_players.to_csv(players_path, index=False)
        existing_players = combined_players
        processed_players.update(new_players_df['Player'])
        print(f"💾 Saved {len(new_players_df)} new player records for {team_name}")

    if new_shots:
        new_shots_df = pd.concat(new_shots, ignore_index=True)
        combined_shots = pd.concat([existing_shots, new_shots_df], ignore_index=True)
        combined_shots.to_csv(shots_path, index=False)
        existing_shots = combined_shots
        print(f"💾 Saved {len(new_shots_df)} new shot records for {team_name}")

    time.sleep(3)  # small delay between teams

print("✅ Finished fetching all remaining player stats and shot charts!")
# Out:
# Fetching roster for Atlanta Hawks...
# ⏭️ Skipping Jacob Toppin (already saved)
# ⏭️ Skipping Jalen Johnson (already saved)
# ⏭️ Skipping Keaton Wallace (already saved)
# ⏭️ Skipping Caris LeVert (already saved)
# ⏭️ Skipping Kobe Bufkin (already saved)
# ⏭️ Skipping Dyson Daniels (already saved)
# ⏭️ Skipping Zaccharie Risacher (already saved)
# ⏭️ Skipping Trae Young (already saved)
# ⏭️ Skipping Terance Mann (already saved)
# ⏭️ Skipping Clint Capela (already saved)
# ⏭️ Skipping Onyeka Okongwu (already saved)
# ⏭️ Skipping Mouhamed Gueye (already saved)
# ⏭️ Skipping Georges Niang (already saved)
# ⏭️ Skipping Larry Nance Jr. (already saved)
# ⏭️ Skipping Garrison Mathews (already saved)
# ⏭️ Skipping Dominick Barlow (already saved)
# ⏭️ Skipping Vít Krejčí (already saved)
# ⏭️ Skipping Daeqwon Plowden (already saved)
#
# Fetching roster for Boston Celtics...
# ⏭️ Skipping Jayson Tatum (already saved)
# ⏭️ Skipping Miles Norris (already saved)
# ⏭️ Skipping Jrue Holiday (already saved)
# ⏭️ Skipping Jaylen Brown (already saved)
# ⏭️ Skipping Kristaps Porziņģis (already saved)
# ⏭️ Skipping Derrick White (already saved)
# ⏭️ Skipping Payton Pritchard (already saved)
# ⏭️ Skipping Torrey Craig (already saved)
# ⏭️ Skipping Drew Peterson (already saved)
# ⏭️ Skipping JD Davison (already saved)
# ⏭️ Skipping Xavier Tillman (already saved)
# ⏭️ Skipping Jordan Walsh (already saved)
# ⏭️ Skipping Sam Hauser (already saved)
# ⏭️ Skipping Luke Kornet (already saved)
# ⏭️ Skipping Al Horford (already saved)
# ⏭️ Skipping Baylor Scheierman (already saved)
# ⏭️ Skipping Neemias Queta (already saved)
#
# Fetching roster for Cleveland Cavaliers...
# ⏭️ Skipping Max Strus (already saved)
# ⏭️ Skipping Ty Jerome (already saved)
# ⏭️ Skipping Evan Mobley (already saved)
# ⏭️ Skipping Sam Merrill (already saved)
# ⏭️ Skipping Javonte Green (already saved)
# ⏭️ Skipping Craig Porter Jr. (already saved)
# ⏭️ Skipping Darius Garland (already saved)
# ⏭️ Skipping De'Andre Hunter (already saved)
# ⏭️ Skipping Tristan Thompson (already saved)
# ⏭️ Skipping Chuma Okeke (already saved)
# ⏭️ Skipping Emoni Bates (already saved)
# ⏭️ Skipping Jaylon Tyson (already saved)
# ⏭️ Skipping Nae'Qwan Tomlin (already saved)
# ⏭️ Skipping Jarrett Allen (already saved)
# ⏭️ Skipping Dean Wade (already saved)
# ⏭️ Skipping Luke Travers (already saved)
# ⏭️ Skipping Isaac Okoro (already saved)
# ⏭️ Skipping Donovan Mitchell (already saved)
#
# Fetching roster for New Orleans Pelicans...
# ⏭️ Skipping Keion Brooks Jr. (already saved)
# ⏭️ Skipping Bruce Brown (already saved)
# ⏭️ Skipping Zion Williamson (already saved)
# ⏭️ Skipping Herbert Jones (already saved)
# ⏭️ Skipping CJ McCollum (already saved)
# ⏭️ Skipping Elfrid Payton (already saved)
# ⏭️ Skipping Jalen Pickett (already saved)
# ⏭️ Skipping Jamal Murray (already saved)
# ⏭️ Skipping Vlatko Čančar (already saved)
# ⏭️ Skipping Aaron Gordon (already saved)
#
# Fetching roster for Golden State Warriors...
# ⏭️ Skipping Gary Payton II (already saved)
# ⏭️ Skipping Jonathan Kuminga (already saved)
# ⏭️ Skipping Taran Armstrong (already saved)
# ⏭️ Skipping Brandin Podziemski (already saved)
# ⏭️ Skipping Moses Moody (already saved)
# ⏭️ Skipping Kevon Looney (already saved)
# ⏭️ Skipping Buddy Hield (already saved)
# ⏭️ Skipping Jimmy Butler III (already saved)
# ⏭️ Skipping Braxton Key (already saved)
# ⏭️ Skipping Gui Santos (already saved)
# ⏭️ Skipping Quinten Post (already saved)
# ⏭️ Skipping Draymond Green (already saved)
# ⏭️ Skipping Stephen Curry (already saved)
# ⏭️ Skipping Kevin Knox II (already saved)
# ⏭️ Skipping Trayce Jackson-Davis (already saved)
# ⏭️ Skipping Jackson Rowe (already saved)
# ⏭️ Skipping Pat Spencer (already saved)
#
# Fetching roster for Houston Rockets...
# ⏭️ Skipping Aaron Holiday (already saved)
# ⏭️ Skipping Amen Thompson (already saved)
# ⏭️ Skipping Jock Landale (already saved)
# ⏭️ Skipping N'Faly Dante (already saved)
# ⏭️ Skipping Jalen Green (already saved)
# ⏭️ Skipping Fred VanVleet (already saved)
# ⏭️ Skipping Cam Whitmore (already saved)
# ⏭️ Skipping Jae'Sean Tate (already saved)
# ⏭️ Skipping Dillon Brooks (already saved)
# ⏭️ Skipping Jabari Smith Jr. (already saved)
# ⏭️ Skipping Steven Adams (already saved)
# ⏭️ Skipping Reed Sheppard (already saved)
# ⏭️ Skipping Tari Eason (already saved)
# ⏭️ Skipping Nate Williams (already saved)
# ⏭️ Skipping Alperen Sengun (already saved)
# ⏭️ Skipping Jeff Green (already saved)
# ⏭️ Skipping David Roddy (already saved)
# ⏭️ Skipping Jack McVeigh (already saved)
#
# Fetching roster for Los Angeles Clippers...
# ⏭️ Skipping James Harden (already saved)
# ⏭️ Skipping Kawhi Leonard (already saved)
# ⏭️ Skipping Seth Lundy (already saved)
# ⏭️ Skipping Amir Coffey (already saved)
# ⏭️ Skipping Kris Dunn (already saved)
# ⏭️ Skipping Trentyn Flowers (already saved)
# ⏭️ Skipping Bogdan Bogdanović (already saved)
# ⏭️ Skipping Jordan Miller (already saved)
# ⏭️ Skipping Cam Christie (already saved)
# ⏭️ Skipping Drew Eubanks (already saved)
# ⏭️ Skipping Kobe Brown (already saved)
# ⏭️ Skipping Patrick Baldwin Jr. (already saved)
# ⏭️ Skipping Norman Powell (already saved)
# ⏭️ Skipping Ben Simmons (already saved)
# ⏭️ Skipping Nicolas Batum (already saved)
# ⏭️ Skipping Ivica Zubac (already saved)
# ⏭️ Skipping Derrick Jones Jr. (already saved)
# ⏭️ Skipping Patty Mills (already saved)
#
# Fetching roster for Los Angeles Lakers...
# ⏭️ Skipping Jarred Vanderbilt (already saved)
# ⏭️ Skipping Dalton Knecht (already saved)
# ⏭️ Skipping Naz Reid (already saved)
# ⏭️ Skipping Tristen Newton (already saved)
# ⏭️ Skipping Jesse Edwards (already saved)
# ⏭️ Skipping Jaylen Clark (already saved)
# ⏭️ Skipping Rudy Gobert (already saved)
# ⏭️ Skipping Julius Randle (already saved)
# ⏭️ Skipping Leonard Miller (already saved)
# ⏭️ Skipping Luka Garza (already saved)
# ⏭️ Skipping Bones Hyland (already saved)
#
# Fetching roster for Brooklyn Nets...
# ⏭️ Skipping Dariq Whitehead (already saved)
# ⏭️ Skipping D'Angelo Russell (already saved)
# ⏭️ Skipping Cameron Johnson (already saved)
# ⏭️ Skipping Reece Beekman (already saved)
# ⏭️ Skipping Ziaire Williams (already saved)
# ⏭️ Skipping Trendon Watford (already saved)
# ⏭️ Skipping Tyson Etienne (already saved)
# ⏭️ Skipping Tosan Evbuomwan (already saved)
# ⏭️ Skipping Tyrese Martin (already saved)
# ⏭️ Skipping De'Anthony Melton (already saved)
# ⏭️ Skipping Day'Ron Sharpe (already saved)
# ⏭️ Skipping Noah Clowney (already saved)
# ⏭️ Skipping Jalen Wilson (already saved)
# ⏭️ Skipping Cam Thomas (already saved)
# ⏭️ Skipping Drew Timme (already saved)
# ⏭️ Skipping Maxwell Lewis (already saved)
# ⏭️ Skipping Nic Claxton (already saved)
# ⏭️ Skipping Keon Johnson (already saved)
#
# Fetching roster for New York Knicks...
# ⏭️ Skipping P.J. Tucker (already saved)
# ⏭️ Skipping Delon Wright (already saved)
# ⏭️ Skipping MarJon Beauchamp (already saved)
# ⏭️ Skipping Cameron Payne (already saved)
# ⏭️ Skipping Miles McBride (already saved)
# ⏭️ Skipping Josh Hart (already saved)
# ⏭️ Skipping Pacôme Dadiet (already saved)
# ⏭️ Skipping Precious Achiuwa (already saved)
# ⏭️ Skipping OG Anunoby (already saved)
# ⏭️ Skipping Kevin McCullar Jr. (already saved)
# ⏭️ Skipping Jalen Brunson (already saved)
# ⏭️ Skipping Tyler Kolek (already saved)
# ⏭️ Skipping Mitchell Robinson (already saved)
# ⏭️ Skipping Mikal Bridges (already saved)
# ⏭️ Skipping Anton Watson (already saved)
# ⏭️ Skipping Karl-Anthony Towns (already saved)
# ⏭️ Skipping Landry Shamet (already saved)
# ⏭️ Skipping Ariel Hukporti (already saved)
#
# Fetching roster for Orlando Magic...
# ⏭️ Skipping Anthony Black (already saved)
# ⏭️ Skipping Jonathan Isaac (already saved)
# ⏭️ Skipping Caleb Houstan (already saved)
# ⏭️ Skipping Desmond Bane (already saved)
# ⏭️ Skipping Jalen Suggs (already saved)
# ⏭️ Skipping Paolo Banchero (already saved)
# ⏭️ Skipping Mac McClung (already saved)
# ⏭️ Skipping Cory Joseph (already saved)
# ⏭️ Skipping Trevelin Queen (already saved)
# ⏭️ Skipping Jett Howard (already saved)
# ⏭️ Skipping Gary Harris (already saved)
# ⏭️ Skipping Moritz Wagner (already saved)
# ⏭️ Skipping Franz Wagner (already saved)
# ⏭️ Skipping Tristan da Silva (already saved)
# ⏭️ Skipping Wendell Carter Jr. (already saved)
#   ✅ Got 164 shots for Seth Curry
#   ✅ Got 114 shots for Tidjane Salaün
#   ✅ Got 47 shots for Taj Gibson
# 💾 Saved 18 new player records for Charlotte Hornets
# 💾 Saved 2793 new shot records for Charlotte Hornets
# ✅ Finished fetching all remaining player stats and shot charts!

# %% [markdown]
# Bug in previous code so need to run script for the rest of the Orlando Magic players from Trevelin Queen to Ethan Thompson

# %%
from nba_api.stats.static import players
# --- Load existing shot data ---
shots_path = "nba_shotchart_data_2024_25.csv"
existing_shots = pd.read_csv(shots_path)

# --- Orlando Magic info ---
team_id = 1610612753
team_name = "Orlando Magic"

# --- Remaining players ---
remaining_players = [
    "Trevelin Queen",
    "Jett Howard",
    "Gary Harris",
    "Moritz Wagner",
    "Franz Wagner",
    "Tristan da Silva",
    "Wendell Carter Jr.",
    "Goga Bitadze",
    "Ethan Thompson"
]

# --- Fetch player IDs ---
all_players = players.get_active_players()
remaining = [p for p in all_players if p['full_name'] in remaining_players]

new_shots = []

for player in remaining:
    player_id = player["id"]
    player_name = player["full_name"]

    # Skip if already exists
    if player_name in existing_shots["PLAYER_NAME"].unique():
        print(f"⏭️ Skipping {player_name} (already in file)")
        continue

    print(f"\n🎯 Fetching shot chart for {player_name}...")

    # --- Shot Chart ---
    try:
        shots = fetch_with_retry(lambda: shotchartdetail.ShotChartDetail(
            team_id=team_id,
            player_id=player_id,
            season_nullable='2024-25',
            season_type_all_star='Regular Season'
        ))

        if shots is not None:
            shots_df = shots.get_data_frames()[0]
            shots_df['PLAYER_ID'] = player_id
            shots_df['PLAYER_NAME'] = player_name
            shots_df['TEAM_NAME'] = team_name
            new_shots.append(shots_df)
            print(f"  ✅ Got {len(shots_df)} shots for {player_name}")
        else:
            print(f"  ⚠️ No shots for {player_name}")

    except Exception as e:
        print(f"  ⚠️ Could not get shots for {player_name}: {e}")

    time.sleep(1.5)

# --- Append and save ---
if new_shots:
    all_shots = pd.concat([existing_shots] + new_shots, ignore_index=True)
    all_shots.to_csv(shots_path, index=False)
    print("\n✅ Successfully appended new shot charts to file.")
else:
    print("\n⚠️ No new shot data was fetched.")
# Out:
# 🎯 Fetching shot chart for Goga Bitadze...
#   ✅ Got 207 shots for Goga Bitadze
#
# 🎯 Fetching shot chart for Wendell Carter Jr....
#   ✅ Got 226 shots for Wendell Carter Jr.
#
# 🎯 Fetching shot chart for Gary Harris...
#   ✅ Got 51 shots for Gary Harris
#
# 🎯 Fetching shot chart for Jett Howard...
#   ✅ Got 98 shots for Jett Howard
#
# 🎯 Fetching shot chart for Trevelin Queen...
#   ✅ Got 56 shots for Trevelin Queen
#
# 🎯 Fetching shot chart for Ethan Thompson...
#   ✅ Got 0 shots for Ethan Thompson
#
# 🎯 Fetching shot chart for Franz Wagner...
#   ✅ Got 537 shots for Franz Wagner
#
# 🎯 Fetching shot chart for Moritz Wagner...
#   ✅ Got 140 shots for Moritz Wagner
#
# 🎯 Fetching shot chart for Tristan da Silva...
#   ✅ Got 199 shots for Tristan da Silva
#
# ✅ Successfully appended new shot charts to file.
